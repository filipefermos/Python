# %%
num = 8

# %%
type(num)
# Out:
# int

# %%
float(num)
# Out:
# 8.0

# %%
x=(3,5,6,7,8,9)

# %%
nova = []
for i in x:
    nova.append(float(i))
print(nova)
# Out:
# [3.0, 5.0, 6.0, 7.0, 8.0, 9.0]
